# %%
# !pip install gradio google-genai pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gradio
#   Using cached gradio-6.26.0-py3-none-any.whl (31.3 MB)
# Collecting google-genai
#   Downloading google_genai-2.22.0-py3-none-any.whl (1.1 MB)
#                                               0.0/1.1 MB ? eta -:--:--
#      -                                        0.0/1.1 MB 1.3 MB/s eta 0:00:01
#      --                                       0.1/1.1 MB 1.3 MB/s eta 0:00:01
#      --------                                 0.2/1.1 MB 1.8 MB/s eta 0:00:01
#      ------------                             0.3/1.1 MB 1.9 MB/s eta 0:00:01
#      --------------------------               0.7/1.1 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------        0.9/1.1 MB 3.6 MB/s eta 0:00:01
#      ---------------------------------------- 1.1/1.1 MB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: pillow in c:\users\admin\appdata\roaming\python\python311\site-packages (11.3.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (3.5.0)
# Collecting brotli>=1.1.0 (from gradio)
#   Using cached brotli-1.2.0-cp311-cp311-win_amd64.whl (369 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Using cached fastapi-0.141.1-py3-none-any.whl (131 kB)
# Collecting gradio-client==2.6.1 (from gradio)
#   Using cached gradio_client-2.6.1-py3-none-any.whl (62 kB)
# Collecting groovy~=0.1 (from gradio)
#   Using cached groovy-0.1.2-py3-none-any.whl (14 kB)
# Collecting hf-gradio<1.0,>=0.4.1 (from gradio)
#   Using cached hf_gradio-0.4.1-py3-none-any.whl (4.5 kB)
# Collecting httpx<1.0,>=0.24.1 (from gradio)
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting huggingface-hub<2.0,>=1.16.0 (from gradio)
#   Downloading huggingface_hub-1.30.0-py3-none-any.whl (796 kB)
#                                               0.0/796.8 kB ? eta -:--:--
#      ------------                          276.5/796.8 kB 16.6 MB/s eta 0:00:01
#      -----------------------------          624.6/796.8 kB 7.9 MB/s eta 0:00:01
#      -------------------------------------- 796.8/796.8 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: jinja2<4.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\admin\appdata\roaming\python\python311\site-packages (from gradio) (1.26.4)
# Collecting orjson~=3.0 (from gradio)
#   Using cached orjson-3.12.0-cp311-cp311-win_amd64.whl (122 kB)
# Requirement already satisfied: packaging in c:\users\admin\appdata\roaming\python\python311\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<4.0,>=1.0 in c:\users\admin\appdata\roaming\python\python311\site-packages (from gradio) (2.3.3)
# Collecting pydantic<=3.0,>=2.0 (from gradio)
#   Using cached pydantic-2.13.5-py3-none-any.whl (472 kB)
# Collecting pydub<1.0 (from gradio)
#   Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart<1.0,>=0.0.18 (from gradio)
#   Using cached python_multipart-0.0.32-py3-none-any.whl (30 kB)
# Requirement already satisfied: pytz>=2017.2 in c:\users\admin\appdata\roaming\python\python311\site-packages (from gradio) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\programdata\anaconda3\lib\site-packages (from gradio) (6.0)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Using cached safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting starlette<2.0,>=1.0.1 (from gradio)
#   Using cached starlette-1.6.0-py3-none-any.whl (75 kB)
# Collecting tomlkit<0.15.0,>=0.12.0 (from gradio)
#   Using cached tomlkit-0.14.0-py3-none-any.whl (39 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Using cached typer-0.27.2-py3-none-any.whl (123 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\admin\appdata\roaming\python\python311\site-packages (from gradio) (4.15.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Using cached uvicorn-0.52.4-py3-none-any.whl (79 kB)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from gradio-client==2.6.1->gradio) (2023.3.0)
# Collecting anyio<5.0,>=3.0 (from gradio)
#   Downloading anyio-4.15.1-py3-none-any.whl (132 kB)
#                                               0.0/132.1 kB ? eta -:--:--
#      -------------------------------------- 132.1/132.1 kB 3.8 MB/s eta 0:00:00
# Collecting google-auth[requests]<3.0.0,>=2.56.0 (from google-genai)
#   Downloading google_auth-2.57.1-py3-none-any.whl (259 kB)
#                                               0.0/260.0 kB ? eta -:--:--
#      ----------------------                   143.4/260.0 kB ? eta -:--:--
#      -------------------------------------- 260.0/260.0 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\programdata\anaconda3\lib\site-packages (from google-genai) (2.29.0)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai)
#   Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Collecting websockets<17.0,>=13.0.0 (from google-genai)
#   Using cached websockets-16.1.1-cp311-cp311-win_amd64.whl (180 kB)
# Collecting distro<2,>=1.7.0 (from google-genai)
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from google-genai) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.4)
# Collecting typing-extensions~=4.0 (from gradio)
#   Downloading typing_extensions-4.16.0-py3-none-any.whl (45 kB)
#                                               0.0/45.6 kB ? eta -:--:--
#      ---------------------------------------- 45.6/45.6 kB 2.4 MB/s eta 0:00:00
# Collecting typing-inspection>=0.4.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Using cached typing_inspection-0.4.4-py3-none-any.whl (14 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Using cached annotated_doc-0.0.5-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.2.8)
# Requirement already satisfied: cryptography>=38.0.3 in c:\programdata\anaconda3\lib\site-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (39.0.1)
# Collecting requests<3.0.0,>=2.28.1 (from google-genai)
#   Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2023.5.7)
# Collecting httpcore==1.* (from httpx<1.0,>=0.24.1->gradio)
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio)
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub<2.0,>=1.16.0->gradio)
#   Using cached click-8.5.0-py3-none-any.whl (125 kB)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=1.16.0->gradio)
#   Using cached filelock-3.32.5-py3-none-any.whl (100 kB)
# Collecting fsspec (from gradio-client==2.6.1->gradio)
#   Using cached fsspec-2026.7.0-py3-none-any.whl (206 kB)
# Collecting hf-xet<2.0.0,>=1.5.2 (from huggingface-hub<2.0,>=1.16.0->gradio)
#   Using cached hf_xet-1.6.0-cp38-abi3-win_amd64.whl (4.0 MB)
# Requirement already satisfied: tqdm>=4.42.1 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.16.0->gradio) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\roaming\python\python311\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\roaming\python\python311\site-packages (from pandas<4.0,>=1.0->gradio) (2025.2)
# Collecting annotated-types>=0.6.0 (from pydantic<=3.0,>=2.0->gradio)
#   Using cached annotated_types-0.8.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.46.5 (from pydantic<=3.0,>=2.0->gradio)
#   Downloading pydantic_core-2.46.5-cp311-cp311-win_amd64.whl (2.0 MB)
#                                               0.0/2.0 MB ? eta -:--:--
#      ---------                                0.5/2.0 MB 30.7 MB/s eta 0:00:01
#      ------------                             0.6/2.0 MB 9.6 MB/s eta 0:00:01
#      ------------------                       0.9/2.0 MB 8.3 MB/s eta 0:00:01
#      --------------------------               1.4/2.0 MB 10.9 MB/s eta 0:00:01
#      --------------------------------         1.7/2.0 MB 8.1 MB/s eta 0:00:01
#      ---------------------------------------  2.0/2.0 MB 8.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (1.26.16)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting rich>=13.8.0 (from typer<1.0,>=0.12->gradio)
#   Downloading rich-15.0.0-py3-none-any.whl (310 kB)
#                                               0.0/310.7 kB ? eta -:--:--
#      -                                        10.2/310.7 kB ? eta -:--:--
#      -------------------------------------  307.2/310.7 kB 4.7 MB/s eta 0:00:01
#      -------------------------------------- 310.7/310.7 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (1.15.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.8)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.21)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Installing collected packages: pydub, brotli, websockets, typing-extensions, tomlkit, tenacity, shellingham, semantic-version, requests, python-multipart, orjson, hf-xet, h11, groovy, fsspec, filelock, distro, click, annotated-types, annotated-doc, uvicorn, typing-inspection, rich, pydantic-core, httpcore, anyio, typer, starlette, pydantic, httpx, google-auth, safehttpx, huggingface-hub, fastapi, gradio-client, google-genai, hf-gradio, gradio
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
# Successfully installed annotated-doc-0.0.5 annotated-types-0.8.0 anyio-4.15.1 brotli-1.2.0 click-8.5.0 distro-1.9.0 fastapi-0.141.1 filelock-3.32.5 fsspec-2026.7.0 google-auth-2.57.1 google-genai-2.22.0 gradio-6.26.0 gradio-client-2.6.1 groovy-0.1.2 h11-0.16.0 hf-gradio-0.4.1 hf-xet-1.6.0 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.30.0 orjson-3.12.0 pydantic-2.13.5 pydantic-core-2.46.5 pydub-0.25.1 python-multipart-0.0.32 requests-2.34.2 rich-15.0.0 safehttpx-0.1.7 semantic-version-2.10.0 shellingham-1.5.4 starlette-1.6.0 tenacity-9.1.4 tomlkit-0.14.0 typer-0.27.2 typing-extensions-4.16.0 typing-inspection-0.4.4 uvicorn-0.52.4 websockets-16.1.1
#   WARNING: The script websockets.exe is installed in 'C:\Users\admin\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script distro.exe is installed in 'C:\Users\admin\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script uvicorn.exe is installed in 'C:\Users\admin\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script typer.exe is installed in 'C:\Users\admin\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'C:\Users\admin\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts hf.exe, huggingface-cli.exe and tiny-agents.exe are installed in 'C:\Users\admin\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script fastapi.exe is installed in 'C:\Users\admin\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script hf-gradio.exe is installed in 'C:\Users\admin\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts gradio.exe and upload_theme.exe are installed in 'C:\Users\admin\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# transformers 2.1.1 requires sentencepiece, which is not installed.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# conda-repo-cli 1.0.41 requires python-dateutil==2.8.2, but you have python-dateutil 2.9.0.post0 which is incompatible.
# conda-repo-cli 1.0.41 requires requests==2.28.1, but you have requests 2.34.2 which is incompatible.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.
# s3fs 2023.3.0 requires fsspec==2023.3.0, but you have fsspec 2026.7.0 which is incompatible.

# %%
import os
from PIL import Image
import gradio as gr
from google import genai
api_key = "YOUR API KEY"
client = genai.Client(api_key=api_key)

# 2. Define Image Captioning Function
def captioner(image):
    if image is None:
        return "Please upload an image."
    try:
        prompt = "Write a short, descriptive caption for this image."
        response = client.models.generate_content(
            model='gemini-3.6-flash',
            contents=[image, prompt]
        )
        return response.text
    except Exception as e:
        return f"Error: {str(e)}"

# 3. Build & Launch Gradio Interface
gr.close_all()

demo = gr.Interface(
    fn=captioner,
    inputs=[gr.Image(label="Upload image", type="pil")],
    outputs=[gr.Textbox(label="Caption", lines=3)],
    title="Image Captioning with Gemini",
    description="Upload an image to generate a descriptive caption using Gemini 3.6 Flash.",
    flagging_mode="never"
)

# Launches inline inside your Jupyter Notebook
demo.launch(inline=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
